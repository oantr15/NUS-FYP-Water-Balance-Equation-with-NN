# %% [markdown]
# # A physics-aware DL model for hydrologic modeling
#
# Recently, Jiang et al. (2020) developed a general approach to educating AI geoscientific knowledge by wrapping physical approaches, speciﬁcally dynamic geoscientific models, as special neural layers into a deep learning (DL) architecture. In that study, rainfall-runoff modeling in 569 catchments across the conterminous United States (CONUS) is used here as an illustrative case.
#
# The key step of implementing the physics-aware DL model is the development of the P-RNN layer, by which physical knowledge can be seamlessly implanted into a DL architecture. This simlple example will show how to use the developed P-RNN layer for rainfall-runoff modelling and show how to replicate SI Figure S5 of the paper in which one model is trained per basin.
#
# Note: This is not an exact replication of the model setup, but can be easily extended to the settings of the paper.
#
# For running this notebook, no GPU is required, and everything should run fine on a standard CPU.
#
# If you use this repository in your work, please cite:
#
# Jiang, S., Zheng, Y., and Solomatine, D. (2020) Improving AI system awareness of geoscience knowledge: Symbiotic integration of physical approaches and deep learning, *Geophysical Research Letters*, 47. https://doi.org/10.1029/2020GL088229
#
# Date: 10.06.2020
#
# Created by: Shijie Jiang (jiangsj(at)mail.sustech.edu.cn)

# %%
## Import dependent libraries
import os
import logging
import numpy as np
import pandas as pd
import tensorflow as tf
from pathlib import Path
from keras.models import Model
from keras.layers import Input, Concatenate
from keras import optimizers, callbacks
from matplotlib import pyplot as plt
from datetime import datetime, timedelta

## Import libraries developed by this study
from libs.hydrolayer import PRNNLayer, ConvLayer, ScaleLayer
from libs.hydrodata import DataforIndividual
from libs import hydroutils

## Ignore all the warnings
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['KMP_WARNINGS'] = '0'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Please change the following working path to your owns.**

# %%
working_path = os.getcwd()

# %% [markdown]
# ## 1. Prepare data
#
# ### 1.1. Load data
#
# Here we use a custom class `DataforIndividual` imported from `libs.hydrodata` for preprocessing the downloaded CAMELS data set.
#
# The data has 6 dims, including 5 inputs (daily precipitation (***prcp***), daily mean temperature (***tmean***), day length (***dayl***), as well as average solar radiation (***srad***) and vapor pressure (***vp***)) and 1 output (runoff (***q***)).

# %%
####################
#   Basin set up   #
####################
basin_id = '01169000' # The basin_id can be changed to any 8-digit basin id contained in the basin_list.txt

hydrodata = DataforIndividual(working_path, basin_id).load_data()

# Plot the data loaded for overview
fig, [ax1, ax2, ax3, ax4, ax5, ax6] = plt.subplots(nrows=6, ncols=1, sharex='row', figsize=(15, 18))

ax1.plot(hydrodata['prcp(mm/day)'])
ax2.plot(hydrodata['tmean(C)'])
ax3.plot(hydrodata['dayl(day)'])
ax4.plot(hydrodata['srad(W/m2)'])
ax5.plot(hydrodata['vp(Pa)'])
ax6.plot(hydrodata['flow(mm)'])

ax1.set_title(f"Basin {basin_id}")
ax1.set_ylabel("prcp(mm/day)")
ax2.set_ylabel("tmean(C)")
ax3.set_ylabel("dayl(day)")
ax4.set_ylabel("srad(W/m2)")
ax5.set_ylabel("vp(Pa)")
ax6.set_ylabel("flow(mm)")

plt.show()
# Out:
# Data in basin #01169000 at huc #01 has been successfully loaded.

# %% [markdown]
# ### 1.2. Split data set for training and testing

# %%
####################
#  Period set up   #
####################

training_start = '1980-10-01'
training_end= '2000-09-30'

# The REAL evaluation period is from '2000-10-01', while the model needs one-year of data for spinning up the model
testing_start = '1999-10-01' 
testing_end= '2010-09-30'

# Split data set to training_set and testing_set
train_set = hydrodata[hydrodata.index.isin(pd.date_range(training_start, training_end))]
test_set = hydrodata[hydrodata.index.isin(pd.date_range(testing_start, testing_end))]

print(f"The training data set is from {training_start} to {training_end}, with a shape of {train_set.shape}")
print(f"The testing data set is from {testing_start} to {testing_end}, with a shape of {test_set.shape}")
# Out:
# The training data set is from 1980-10-01 to 2000-09-30, with a shape of (7305, 6)
# The testing data set is from 1999-10-01 to 2010-09-30, with a shape of (4018, 6)

# %% [markdown]
# ### 1.3. Generate traning and testing samples
#
# Due to the recursive operation in RNN, a long time sequence would significantly decrease the efficiency of the training process. For speeding up the learning process, here we divide the long training time sequence into smaller sequences (say each of which has a length of 6 years). The interval between the start date of two continual sequences is 365 days (indicating overlaps between the sequences).
#
# This strategy can not only imporve the efficiency but also increase the sample size (otherwise only one sample is trained per basin).

# %%
def generate_train_test(train_set, test_set, wrap_length):
    train_x_np = train_set.values[:, :-1]
    train_y_np = train_set.values[:, -1:]
    test_x_np = test_set.values[:, :-1]
    test_y_np = test_set.values[:, -1:]
    
    wrap_number_train = (train_set.shape[0]-wrap_length)//365 + 1
    
    train_x = np.empty(shape = (wrap_number_train, wrap_length, train_x_np.shape[1]))
    train_y = np.empty(shape = (wrap_number_train, wrap_length, train_y_np.shape[1]))

    test_x = np.expand_dims(test_x_np, axis=0)
    test_y = np.expand_dims(test_y_np, axis=0)
    
    for i in range(wrap_number_train):
        train_x[i, :, :] = train_x_np[i*365:(wrap_length+i*365), :]
        train_y[i, :, :] = train_y_np[i*365:(wrap_length+i*365), :]
             
    return train_x, train_y, test_x, test_y

wrap_length=2190 # It can be other values, but recommend this value should not be less than 5 years (1825 days).
train_x, train_y, test_x, test_y = generate_train_test(train_set, test_set, wrap_length=wrap_length)

print(f'The shape of train_x, train_y, test_x, and test_y after wrapping by {wrap_length} days are:')
print(f'{train_x.shape}, {train_y.shape}, {test_x.shape}, and {test_y.shape}')
# Out:
# The shape of train_x, train_y, test_x, and test_y after wrapping by 2190 days are:
# (15, 2190, 5), (15, 2190, 1), (1, 4018, 5), and (1, 4018, 1)

# %% [markdown]
# ## 2. Model building and evaluating
#
# ### 2.1. Utilities for creating, training, and testing the model
#
# First we implement three functions for creating, training, and testing the model.
#
# - `create_model()`: This function is used for create a Keras model in the following type:
#   - `hybrid` : The hybird DL model containing both physical part and data-driven part.
#   - `physical`: The physical NN model only containing the physical part (P-RNN layer).
#   - `common`: The common NN model only containing the data-driven part (1D-CNN layer).
#
# - `train_model()`: This function is used for training the Keras model  by the training data set.
#
# - `test_model()`: This function is used for evaluating the Keras model by the testing data set.

# %%
def create_model(input_shape, seed, num_filters, model_type='hybrid'):
    """Create a Keras model.
    -- input_shape: the shape of input, controlling the time sequence length of the P-RNN
    -- seed: the random seed for the weights initialization of the 1D-CNN layers
    -- num_filters: the number of filters for the 1D-CNN layer
    -- model_type: can be 'hybrid', 'physical', or 'common'
    """
    
    x_input = Input(shape=input_shape, name='Input')
    
    if model_type == 'hybrid':
        hydro_output = PRNNLayer(mode= 'normal', name='Hydro')(x_input)
        x_hydro = Concatenate(axis=-1, name='Concat')([x_input, hydro_output])
        x_scale = ScaleLayer(name='Scale')(x_hydro)
        cnn_output = ConvLayer(filters=num_filters, kernel_size=10, padding='causal', seed=seed, name='Conv1')(x_scale)
        cnn_output = ConvLayer(filters=1, kernel_size=1, padding='causal', seed=seed, name='Conv2')(cnn_output)
        model = Model(x_input, cnn_output)
    
    elif model_type == 'physical':
        hydro_output = PRNNLayer(mode= 'normal', name='Hydro')(x_input)
        model = Model(x_input, hydro_output)
    
    elif model_type == 'common':
        cnn_output = ConvLayer(filters=num_filters, kernel_size=10, padding='causal', seed=seed, name='Conv1')(x_input)
        cnn_output = ConvLayer(filters=1, kernel_size=1, padding='causal', seed=seed, name='Conv2')(cnn_output)
        model = Model(x_input, cnn_output)
    
    return model

def train_model(model, train_x, train_y, ep_number, lrate, save_path):
    """Train a Keras model.
    -- model: the Keras model object
    -- train_x, train_y: the input and target for training the model
    -- ep_number: the maximum epoch number
    -- lrate: the initial learning rate
    -- save_path: where the model will be saved
    """
    
    save = callbacks.ModelCheckpoint(save_path, verbose=0, save_best_only=True, monitor='nse_metrics', mode='max',
                                     save_weights_only=True)
    es = callbacks.EarlyStopping(monitor='nse_metrics', mode='max', verbose=1, patience=20, min_delta=0.005,
                                 restore_best_weights=True)
    reduce = callbacks.ReduceLROnPlateau(monitor='nse_metrics', factor=0.8, patience=5, verbose=1, mode='max',
                                         min_delta=0.005, cooldown=0, min_lr=lrate / 100)
    tnan = callbacks.TerminateOnNaN()

    model.compile(loss=hydroutils.nse_loss, metrics=[hydroutils.nse_metrics], optimizer=optimizers.Adam(lr=lrate))
    history = model.fit(train_x, train_y, epochs=ep_number, batch_size=10000, callbacks=[save, es, reduce, tnan])
    
    return history
    
def test_model(model, test_x, save_path):
    """Test a Keras model.
    -- model: the Keras model object
    -- test_x: the input for testing the model
    -- save_path: where the model was be saved
    """
    model.load_weights(save_path, by_name=True)
    pred_y = model.predict(test_x, batch_size=10000)
    
    return pred_y

# %% [markdown]
# ### 2.2. Train the hybrid model
#
# Here we call the `create_model()` and `train_model()` functions to building and training the hybrid DL model.

# %%
Path(f'{working_path}/results').mkdir(parents=True, exist_ok=True)
save_path_hybrid = f'{working_path}/results/{basin_id}_hybrid.h5'

model = create_model((train_x.shape[1], train_x.shape[2]), seed = 200, num_filters = 8, model_type='hybrid')
model.summary()
hybrid_history = train_model(model, train_x, train_y, ep_number=200, lrate=0.01, save_path=save_path_hybrid)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 2190, 5)      0
# __________________________________________________________________________________________________
# Hydro (PRNNLayer)               (None, 2190, 1)      6           Input[0][0]
# __________________________________________________________________________________________________
# Concat (Concatenate)            (None, 2190, 6)      0           Input[0][0]
#                                                                  Hydro[0][0]
# __________________________________________________________________________________________________
# Scale (ScaleLayer)              (None, 2190, 6)      0           Concat[0][0]
# __________________________________________________________________________________________________
# Conv1 (ConvLayer)               (None, 2190, 8)      488         Scale[0][0]
# __________________________________________________________________________________________________
# Conv2 (ConvLayer)               (None, 2190, 1)      9           Conv1[0][0]
# ==================================================================================================
# Total params: 503
# Trainable params: 503
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 15/15 [==============================] - 5s 318ms/step - loss: 1.4322 - nse_metrics: -0.4322
# Epoch 2/200
# 15/15 [==============================] - 2s 139ms/step - loss: 1.3886 - nse_metrics: -0.3886
# Epoch 3/200
# 15/15 [==============================] - 2s 152ms/step - loss: 1.3457 - nse_metrics: -0.3457
# Epoch 4/200
# 15/15 [==============================] - 2s 147ms/step - loss: 1.3023 - nse_metrics: -0.3023
# Epoch 5/200
# 15/15 [==============================] - 2s 146ms/step - loss: 1.2520 - nse_metrics: -0.2520
# Epoch 6/200
# 15/15 [==============================] - 3s 168ms/step - loss: 1.1987 - nse_metrics: -0.1987
# Epoch 7/200
# 15/15 [==============================] - 2s 149ms/step - loss: 1.1393 - nse_metrics: -0.1393
# Epoch 8/200
# 15/15 [==============================] - 3s 176ms/step - loss: 1.0747 - nse_metrics: -0.0747
# Epoch 9/200
# 15/15 [==============================] - 3s 206ms/step - loss: 1.0067 - nse_metrics: -0.0067
# Epoch 10/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.9372 - nse_metrics: 0.0628
# Epoch 11/200
# 15/15 [==============================] - 2s 158ms/step - loss: 0.8687 - nse_metrics: 0.1313
# Epoch 12/200
# 15/15 [==============================] - 2s 159ms/step - loss: 0.8036 - nse_metrics: 0.1964
# Epoch 13/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.7445 - nse_metrics: 0.2555
# Epoch 14/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.6940 - nse_metrics: 0.3060
# Epoch 15/200
# 15/15 [==============================] - 2s 140ms/step - loss: 0.6539 - nse_metrics: 0.3461
# Epoch 16/200
# 15/15 [==============================] - 2s 146ms/step - loss: 0.6254 - nse_metrics: 0.3746
# Epoch 17/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.6081 - nse_metrics: 0.3919
# Epoch 18/200
# 15/15 [==============================] - 2s 143ms/step - loss: 0.6003 - nse_metrics: 0.3997
# Epoch 19/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.5977 - nse_metrics: 0.4023
# Epoch 20/200
# 15/15 [==============================] - 2s 152ms/step - loss: 0.5960 - nse_metrics: 0.4040
# Epoch 21/200
# 15/15 [==============================] - 2s 147ms/step - loss: 0.5921 - nse_metrics: 0.4079
# Epoch 22/200
# 15/15 [==============================] - 2s 154ms/step - loss: 0.5834 - nse_metrics: 0.4166
# Epoch 23/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.5693 - nse_metrics: 0.4307
# Epoch 24/200
# 15/15 [==============================] - 2s 142ms/step - loss: 0.5498 - nse_metrics: 0.4502
# Epoch 25/200
# 15/15 [==============================] - 2s 144ms/step - loss: 0.5270 - nse_metrics: 0.4730
# Epoch 26/200
# 15/15 [==============================] - 2s 143ms/step - loss: 0.5025 - nse_metrics: 0.4975
# Epoch 27/200
# 15/15 [==============================] - 2s 146ms/step - loss: 0.4782 - nse_metrics: 0.5218
# Epoch 28/200
# 15/15 [==============================] - 2s 139ms/step - loss: 0.4554 - nse_metrics: 0.5446
# Epoch 29/200
# 15/15 [==============================] - 2s 137ms/step - loss: 0.4354 - nse_metrics: 0.5646
# Epoch 30/200
# 15/15 [==============================] - 2s 139ms/step - loss: 0.4184 - nse_metrics: 0.5816
# Epoch 31/200
# 15/15 [==============================] - 2s 136ms/step - loss: 0.4043 - nse_metrics: 0.5957
# Epoch 32/200
# 15/15 [==============================] - 2s 137ms/step - loss: 0.3927 - nse_metrics: 0.6073
# Epoch 33/200
# 15/15 [==============================] - 2s 137ms/step - loss: 0.3841 - nse_metrics: 0.6159
# Epoch 34/200
# 15/15 [==============================] - 2s 150ms/step - loss: 0.3770 - nse_metrics: 0.6230
# Epoch 35/200
# 15/15 [==============================] - 6s 400ms/step - loss: 0.3701 - nse_metrics: 0.6299
# Epoch 36/200
# 15/15 [==============================] - 3s 181ms/step - loss: 0.3635 - nse_metrics: 0.6365
# Epoch 37/200
# 15/15 [==============================] - 2s 144ms/step - loss: 0.3554 - nse_metrics: 0.6446
# Epoch 38/200
# 15/15 [==============================] - 5s 311ms/step - loss: 0.3463 - nse_metrics: 0.6537
# Epoch 39/200
# 15/15 [==============================] - 5s 304ms/step - loss: 0.3371 - nse_metrics: 0.6629
# Epoch 40/200
# 15/15 [==============================] - 3s 204ms/step - loss: 0.3285 - nse_metrics: 0.6715
# Epoch 41/200
# 15/15 [==============================] - 3s 186ms/step - loss: 0.3207 - nse_metrics: 0.6793
# Epoch 42/200
# 15/15 [==============================] - 3s 176ms/step - loss: 0.3140 - nse_metrics: 0.6860
# Epoch 43/200
# 15/15 [==============================] - 3s 182ms/step - loss: 0.3096 - nse_metrics: 0.6904
# Epoch 44/200
# 15/15 [==============================] - 3s 188ms/step - loss: 0.3075 - nse_metrics: 0.6925
# Epoch 45/200
# 15/15 [==============================] - 3s 193ms/step - loss: 0.3062 - nse_metrics: 0.6938
# Epoch 46/200
# 15/15 [==============================] - 3s 185ms/step - loss: 0.3042 - nse_metrics: 0.6958
# Epoch 47/200
# 15/15 [==============================] - 2s 165ms/step - loss: 0.3013 - nse_metrics: 0.6987
# Epoch 48/200
# 15/15 [==============================] - 2s 166ms/step - loss: 0.2979 - nse_metrics: 0.7021
# Epoch 49/200
# 15/15 [==============================] - 3s 193ms/step - loss: 0.2945 - nse_metrics: 0.7055
# Epoch 50/200
# 15/15 [==============================] - 3s 173ms/step - loss: 0.2915 - nse_metrics: 0.7085
# Epoch 51/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.2888 - nse_metrics: 0.7112
# Epoch 52/200
# 15/15 [==============================] - 2s 155ms/step - loss: 0.2868 - nse_metrics: 0.7132
# Epoch 53/200
# 15/15 [==============================] - 2s 165ms/step - loss: 0.2850 - nse_metrics: 0.7150
# Epoch 54/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.2833 - nse_metrics: 0.7167
# Epoch 55/200
# 15/15 [==============================] - 2s 164ms/step - loss: 0.2818 - nse_metrics: 0.7182
# Epoch 56/200
# 15/15 [==============================] - 3s 182ms/step - loss: 0.2802 - nse_metrics: 0.7198
# Epoch 57/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.2783 - nse_metrics: 0.7217
# Epoch 58/200
# 15/15 [==============================] - 2s 165ms/step - loss: 0.2770 - nse_metrics: 0.7230
# Epoch 59/200
# 15/15 [==============================] - 3s 167ms/step - loss: 0.2756 - nse_metrics: 0.7244
# Epoch 60/200
# 15/15 [==============================] - 2s 164ms/step - loss: 0.2748 - nse_metrics: 0.7252
# Epoch 61/200
# 15/15 [==============================] - 3s 170ms/step - loss: 0.2735 - nse_metrics: 0.7265
# Epoch 62/200
# 15/15 [==============================] - 3s 171ms/step - loss: 0.2722 - nse_metrics: 0.7278
# Epoch 63/200
# 15/15 [==============================] - 2s 162ms/step - loss: 0.2711 - nse_metrics: 0.7289
# Epoch 64/200
# 15/15 [==============================] - 2s 160ms/step - loss: 0.2699 - nse_metrics: 0.7301
# Epoch 65/200
# 15/15 [==============================] - 3s 171ms/step - loss: 0.2685 - nse_metrics: 0.7315
# Epoch 66/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.2671 - nse_metrics: 0.7329
# Epoch 67/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.2659 - nse_metrics: 0.7341
# Epoch 68/200
# 15/15 [==============================] - 2s 155ms/step - loss: 0.2648 - nse_metrics: 0.7352
# Epoch 69/200
# 15/15 [==============================] - 3s 172ms/step - loss: 0.2639 - nse_metrics: 0.7361
# Epoch 70/200
# 15/15 [==============================] - 2s 165ms/step - loss: 0.2629 - nse_metrics: 0.7371
# Epoch 71/200
# 15/15 [==============================] - 2s 151ms/step - loss: 0.2621 - nse_metrics: 0.7379
# Epoch 72/200
# 15/15 [==============================] - 2s 160ms/step - loss: 0.2613 - nse_metrics: 0.7387
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# Epoch 73/200
# 15/15 [==============================] - 2s 164ms/step - loss: 0.2605 - nse_metrics: 0.7395
# Epoch 74/200
# 15/15 [==============================] - 2s 156ms/step - loss: 0.2599 - nse_metrics: 0.7401
# Epoch 75/200
# 15/15 [==============================] - 3s 170ms/step - loss: 0.2593 - nse_metrics: 0.7407
# Epoch 76/200
# 15/15 [==============================] - 2s 163ms/step - loss: 0.2588 - nse_metrics: 0.7412
# Epoch 77/200
# 15/15 [==============================] - 2s 156ms/step - loss: 0.2583 - nse_metrics: 0.7417
# Epoch 78/200
# 15/15 [==============================] - 2s 145ms/step - loss: 0.2577 - nse_metrics: 0.7423
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.006399999558925629.
# Epoch 79/200
# 15/15 [==============================] - 2s 147ms/step - loss: 0.2572 - nse_metrics: 0.7428
# Epoch 80/200
# 15/15 [==============================] - 2s 150ms/step - loss: 0.2567 - nse_metrics: 0.7433
# Epoch 81/200
# 15/15 [==============================] - 2s 154ms/step - loss: 0.2562 - nse_metrics: 0.7438
# Epoch 82/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.2557 - nse_metrics: 0.7443
# Epoch 83/200
# 15/15 [==============================] - 2s 145ms/step - loss: 0.2552 - nse_metrics: 0.7448
# Epoch 84/200
# 15/15 [==============================] - 2s 147ms/step - loss: 0.2548 - nse_metrics: 0.7452
# Epoch 85/200
# 15/15 [==============================] - 2s 146ms/step - loss: 0.2544 - nse_metrics: 0.7456
# Epoch 86/200
# 15/15 [==============================] - 2s 146ms/step - loss: 0.2540 - nse_metrics: 0.7460
# Epoch 87/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.2536 - nse_metrics: 0.7464
# Epoch 88/200
# 15/15 [==============================] - 2s 164ms/step - loss: 0.2532 - nse_metrics: 0.7468
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.0051199994981288915.
# Epoch 89/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.2527 - nse_metrics: 0.7473
# Epoch 90/200
# 15/15 [==============================] - 2s 144ms/step - loss: 0.2524 - nse_metrics: 0.7476
# Epoch 91/200
# 15/15 [==============================] - 2s 149ms/step - loss: 0.2521 - nse_metrics: 0.7479
# Epoch 92/200
# 15/15 [==============================] - 2s 151ms/step - loss: 0.2518 - nse_metrics: 0.7482
# Epoch 93/200
# 15/15 [==============================] - 2s 147ms/step - loss: 0.2516 - nse_metrics: 0.7484
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.004095999523997307.
# Epoch 94/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.2513 - nse_metrics: 0.7487
# Epoch 95/200
# 15/15 [==============================] - 2s 146ms/step - loss: 0.2511 - nse_metrics: 0.7489
# Epoch 96/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.2508 - nse_metrics: 0.7492
# Epoch 97/200
# 15/15 [==============================] - 2s 149ms/step - loss: 0.2506 - nse_metrics: 0.7494
# Epoch 98/200
# 15/15 [==============================] - 2s 149ms/step - loss: 0.2503 - nse_metrics: 0.7497
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.0032767996191978457.
# Epoch 99/200
# 15/15 [==============================] - 2s 146ms/step - loss: 0.2501 - nse_metrics: 0.7499
# Epoch 100/200
# 15/15 [==============================] - 2s 145ms/step - loss: 0.2499 - nse_metrics: 0.7501
# Epoch 101/200
# 15/15 [==============================] - 2s 145ms/step - loss: 0.2497 - nse_metrics: 0.7503
# Epoch 102/200
# 15/15 [==============================] - 3s 173ms/step - loss: 0.2495 - nse_metrics: 0.7505
# Epoch 103/200
# 15/15 [==============================] - 2s 160ms/step - loss: 0.2493 - nse_metrics: 0.7507
# Epoch 104/200
# 15/15 [==============================] - 2s 151ms/step - loss: 0.2491 - nse_metrics: 0.7509
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 0.0026214396581053737.
# Epoch 105/200
# 15/15 [==============================] - 2s 148ms/step - loss: 0.2489 - nse_metrics: 0.7511
# Epoch 106/200
# 15/15 [==============================] - 2s 151ms/step - loss: 0.2488 - nse_metrics: 0.7512
# Epoch 107/200
# 15/15 [==============================] - 2s 149ms/step - loss: 0.2487 - nse_metrics: 0.7513
# Epoch 108/200
# 15/15 [==============================] - 2s 149ms/step - loss: 0.2485 - nse_metrics: 0.7515
# Epoch 109/200
# 15/15 [==============================] - 2s 142ms/step - loss: 0.2484 - nse_metrics: 0.7516
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 0.0020971518009901048.
# Epoch 110/200
# 15/15 [==============================] - 2s 150ms/step - loss: 0.2483 - nse_metrics: 0.7517
# Epoch 111/200
# 15/15 [==============================] - 2s 150ms/step - loss: 0.2481 - nse_metrics: 0.7519
# Epoch 112/200
# 15/15 [==============================] - 2s 144ms/step - loss: 0.2480 - nse_metrics: 0.7520
# Epoch 113/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.2479 - nse_metrics: 0.7521
# Epoch 114/200
# 15/15 [==============================] - 3s 191ms/step - loss: 0.2478 - nse_metrics: 0.7522
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 0.0016777213662862779.
# Epoch 115/200
# 15/15 [==============================] - 2s 163ms/step - loss: 0.2477 - nse_metrics: 0.7523
# Epoch 116/200
# 15/15 [==============================] - 2s 150ms/step - loss: 0.2476 - nse_metrics: 0.7524
# Epoch 117/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.2475 - nse_metrics: 0.7525
# Epoch 118/200
# 15/15 [==============================] - 2s 158ms/step - loss: 0.2474 - nse_metrics: 0.7526
# Epoch 119/200
# 15/15 [==============================] - 2s 155ms/step - loss: 0.2473 - nse_metrics: 0.7527
# Restoring model weights from the end of the best epoch
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 0.0013421771116554739.
# Epoch 00119: early stopping

# %% [markdown]
# ### 2.3. Train the physical model
#
# Here we call the `create_model()` and `train_model()` functions to building and training the physical NN model.

# %%
Path(f'{working_path}/results').mkdir(parents=True, exist_ok=True)
save_path_physical = f'{working_path}/results/{basin_id}_physical.h5'

model = create_model((train_x.shape[1], train_x.shape[2]), seed = 200, num_filters = 8, model_type='physical')
model.summary()
hybrid_history = train_model(model, train_x, train_y, ep_number=200, lrate=0.01, save_path=save_path_physical)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 2190, 5)           0
# _________________________________________________________________
# Hydro (PRNNLayer)            (None, 2190, 1)           6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 15/15 [==============================] - 4s 266ms/step - loss: 0.7267 - nse_metrics: 0.2733
# Epoch 2/200
# 15/15 [==============================] - 2s 165ms/step - loss: 0.6975 - nse_metrics: 0.3025
# Epoch 3/200
# 15/15 [==============================] - 2s 152ms/step - loss: 0.6658 - nse_metrics: 0.3342
# Epoch 4/200
# 15/15 [==============================] - 2s 152ms/step - loss: 0.6415 - nse_metrics: 0.3585
# Epoch 5/200
# 15/15 [==============================] - 2s 155ms/step - loss: 0.6198 - nse_metrics: 0.3802
# Epoch 6/200
# 15/15 [==============================] - 2s 155ms/step - loss: 0.6011 - nse_metrics: 0.3989
# Epoch 7/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.5824 - nse_metrics: 0.4176
# Epoch 8/200
# 15/15 [==============================] - 2s 155ms/step - loss: 0.5669 - nse_metrics: 0.4331
# Epoch 9/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.5534 - nse_metrics: 0.4466
# Epoch 10/200
# 15/15 [==============================] - 2s 152ms/step - loss: 0.5402 - nse_metrics: 0.4598
# Epoch 11/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.5270 - nse_metrics: 0.4730
# Epoch 12/200
# 15/15 [==============================] - 3s 167ms/step - loss: 0.5144 - nse_metrics: 0.4856
# Epoch 13/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.5026 - nse_metrics: 0.4974
# Epoch 14/200
# 15/15 [==============================] - 3s 174ms/step - loss: 0.4924 - nse_metrics: 0.5076
# Epoch 15/200
# 15/15 [==============================] - 3s 174ms/step - loss: 0.4840 - nse_metrics: 0.5160
# Epoch 16/200
# 15/15 [==============================] - 3s 174ms/step - loss: 0.4770 - nse_metrics: 0.5230
# Epoch 17/200
# 15/15 [==============================] - 3s 170ms/step - loss: 0.4712 - nse_metrics: 0.5288
# Epoch 18/200
# 15/15 [==============================] - 2s 154ms/step - loss: 0.4663 - nse_metrics: 0.5337
# Epoch 19/200
# 15/15 [==============================] - 3s 176ms/step - loss: 0.4621 - nse_metrics: 0.5379
# Epoch 20/200
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4585 - nse_metrics: 0.5415
# Epoch 21/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.4554 - nse_metrics: 0.5446
# Epoch 22/200
# 15/15 [==============================] - 3s 173ms/step - loss: 0.4528 - nse_metrics: 0.5472
# Epoch 23/200
# 15/15 [==============================] - 3s 167ms/step - loss: 0.4508 - nse_metrics: 0.5492
# Epoch 24/200
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4492 - nse_metrics: 0.5508
# Epoch 25/200
# 15/15 [==============================] - 3s 174ms/step - loss: 0.4479 - nse_metrics: 0.5521
# Epoch 26/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.4463 - nse_metrics: 0.5537
# Epoch 27/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4445 - nse_metrics: 0.5555
# Epoch 28/200
# 15/15 [==============================] - 3s 183ms/step - loss: 0.4430 - nse_metrics: 0.5570
# Epoch 29/200
# 15/15 [==============================] - 3s 169ms/step - loss: 0.4418 - nse_metrics: 0.5582
# Epoch 30/200
# 15/15 [==============================] - 3s 170ms/step - loss: 0.4406 - nse_metrics: 0.5594
# Epoch 31/200
# 15/15 [==============================] - 3s 173ms/step - loss: 0.4397 - nse_metrics: 0.5603
# Epoch 32/200
# 15/15 [==============================] - 3s 199ms/step - loss: 0.4391 - nse_metrics: 0.5609
# Epoch 33/200
# 15/15 [==============================] - 3s 182ms/step - loss: 0.4378 - nse_metrics: 0.5622
# Epoch 34/200
# 15/15 [==============================] - 3s 199ms/step - loss: 0.4361 - nse_metrics: 0.5639
# Epoch 35/200
# 15/15 [==============================] - 3s 185ms/step - loss: 0.4347 - nse_metrics: 0.5653
# Epoch 36/200
# 15/15 [==============================] - 3s 180ms/step - loss: 0.4333 - nse_metrics: 0.5667
# Epoch 37/200
# 15/15 [==============================] - 3s 182ms/step - loss: 0.4319 - nse_metrics: 0.5681
# Epoch 38/200
# 15/15 [==============================] - 3s 171ms/step - loss: 0.4311 - nse_metrics: 0.5689
# Epoch 39/200
# 15/15 [==============================] - 2s 156ms/step - loss: 0.4305 - nse_metrics: 0.5695
# Epoch 40/200
# 15/15 [==============================] - 3s 174ms/step - loss: 0.4284 - nse_metrics: 0.5716
# Epoch 41/200
# 15/15 [==============================] - 2s 153ms/step - loss: 0.4257 - nse_metrics: 0.5743
# Epoch 42/200
# 15/15 [==============================] - 2s 154ms/step - loss: 0.4216 - nse_metrics: 0.5784
# Epoch 43/200
# 15/15 [==============================] - 2s 158ms/step - loss: 0.4147 - nse_metrics: 0.5853
# Epoch 44/200
# 15/15 [==============================] - 3s 197ms/step - loss: 0.4101 - nse_metrics: 0.5899
# Epoch 45/200
# 15/15 [==============================] - 3s 176ms/step - loss: 0.4059 - nse_metrics: 0.5941
# Epoch 46/200
# 15/15 [==============================] - 3s 168ms/step - loss: 0.4024 - nse_metrics: 0.5976
# Epoch 47/200
# 15/15 [==============================] - 3s 194ms/step - loss: 0.3971 - nse_metrics: 0.6029
# Epoch 48/200
# 15/15 [==============================] - 3s 195ms/step - loss: 0.3901 - nse_metrics: 0.6099
# Epoch 49/200
# 15/15 [==============================] - 2s 163ms/step - loss: 0.3906 - nse_metrics: 0.6094
# Epoch 50/200
# 15/15 [==============================] - 2s 163ms/step - loss: 0.3926 - nse_metrics: 0.6074
# Epoch 51/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.3946 - nse_metrics: 0.6054
# Epoch 52/200
# 15/15 [==============================] - 3s 169ms/step - loss: 0.3965 - nse_metrics: 0.6035
# Epoch 53/200
# 15/15 [==============================] - 3s 169ms/step - loss: 0.3982 - nse_metrics: 0.6018
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# Epoch 54/200
# 15/15 [==============================] - 2s 158ms/step - loss: 0.3994 - nse_metrics: 0.6006
# Epoch 55/200
# 15/15 [==============================] - 2s 158ms/step - loss: 0.3996 - nse_metrics: 0.6004
# Epoch 56/200
# 15/15 [==============================] - 2s 162ms/step - loss: 0.3991 - nse_metrics: 0.6009
# Epoch 57/200
# 15/15 [==============================] - 2s 160ms/step - loss: 0.3980 - nse_metrics: 0.6020
# Epoch 58/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.3966 - nse_metrics: 0.6034
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.006399999558925629.
# Epoch 59/200
# 15/15 [==============================] - 3s 172ms/step - loss: 0.3950 - nse_metrics: 0.6050
# Epoch 60/200
# 15/15 [==============================] - 2s 164ms/step - loss: 0.3938 - nse_metrics: 0.6062
# Epoch 61/200
# 15/15 [==============================] - 2s 158ms/step - loss: 0.3925 - nse_metrics: 0.6075
# Epoch 62/200
# 15/15 [==============================] - 2s 161ms/step - loss: 0.3913 - nse_metrics: 0.6087
# Epoch 63/200
# 15/15 [==============================] - 2s 159ms/step - loss: 0.3899 - nse_metrics: 0.6101
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.0051199994981288915.
# Epoch 64/200
# 15/15 [==============================] - 2s 157ms/step - loss: 0.3882 - nse_metrics: 0.6118
# Epoch 65/200
# 15/15 [==============================] - 2s 162ms/step - loss: 0.3872 - nse_metrics: 0.6128
# Epoch 66/200
# 15/15 [==============================] - 3s 175ms/step - loss: 0.3863 - nse_metrics: 0.6137
# Epoch 67/200
# 15/15 [==============================] - 2s 159ms/step - loss: 0.3870 - nse_metrics: 0.6130
# Epoch 68/200
# 15/15 [==============================] - 2s 156ms/step - loss: 0.3883 - nse_metrics: 0.6117
# Restoring model weights from the end of the best epoch
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.004095999523997307.
# Epoch 00068: early stopping

# %% [markdown]
# ### 2.4. Train the common model
#
# Here we call the `create_model()` and `train_model()` functions to building and training the common NN model.
#
# As the range of inputs and output of the 1D-CNN layer varies broadly, it is better to normalize the target of the training data set for numerical purposes. In this example, we normalize `train_x` and `train_y` with their respective mean and std values at the beginning before training.

# %%
def normalize(data):
    data_mean = np.mean(data, axis=-2, keepdims=True)
    data_std = np.std(data, axis=-2, keepdims=True)
    data_scaled = (data - data_mean) / data_std
    return data_scaled, data_mean, data_std

Path(f'{working_path}/results').mkdir(parents=True, exist_ok=True)
save_path_common = f'{working_path}/results/{basin_id}_common.h5'

model = create_model((train_x.shape[1], train_x.shape[2]), seed = 200, num_filters = 8, model_type='common')
model.summary()

train_x_nor, train_x_mean, train_x_std = normalize(train_x)
train_y_nor, train_y_mean, train_y_std = normalize(train_y)

common_history = train_model(model, train_x_nor, train_y_nor,ep_number=200, lrate=0.01, save_path=save_path_common)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 2190, 5)           0
# _________________________________________________________________
# Conv1 (ConvLayer)            (None, 2190, 8)           408
# _________________________________________________________________
# Conv2 (ConvLayer)            (None, 2190, 1)           9
# =================================================================
# Total params: 417
# Trainable params: 417
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 15/15 [==============================] - 0s 13ms/step - loss: 0.9946 - nse_metrics: 0.0054
# Epoch 2/200
# 15/15 [==============================] - 0s 487us/step - loss: 0.9668 - nse_metrics: 0.0332
# Epoch 3/200
# 15/15 [==============================] - 0s 516us/step - loss: 0.9424 - nse_metrics: 0.0576
# Epoch 4/200
# 15/15 [==============================] - 0s 433us/step - loss: 0.9175 - nse_metrics: 0.0825
# Epoch 5/200
# 15/15 [==============================] - 0s 529us/step - loss: 0.8920 - nse_metrics: 0.1080
# Epoch 6/200
# 15/15 [==============================] - 0s 511us/step - loss: 0.8665 - nse_metrics: 0.1335
# Epoch 7/200
# 15/15 [==============================] - 0s 497us/step - loss: 0.8428 - nse_metrics: 0.1572
# Epoch 8/200
# 15/15 [==============================] - 0s 521us/step - loss: 0.8231 - nse_metrics: 0.1769
# Epoch 9/200
# 15/15 [==============================] - 0s 453us/step - loss: 0.8064 - nse_metrics: 0.1936
# Epoch 10/200
# 15/15 [==============================] - 0s 493us/step - loss: 0.7895 - nse_metrics: 0.2105
# Epoch 11/200
# 15/15 [==============================] - 0s 527us/step - loss: 0.7708 - nse_metrics: 0.2292
# Epoch 12/200
# 15/15 [==============================] - 0s 535us/step - loss: 0.7510 - nse_metrics: 0.2490
# Epoch 13/200
# 15/15 [==============================] - 0s 479us/step - loss: 0.7309 - nse_metrics: 0.2691
# Epoch 14/200
# 15/15 [==============================] - 0s 477us/step - loss: 0.7112 - nse_metrics: 0.2888
# Epoch 15/200
# 15/15 [==============================] - 0s 438us/step - loss: 0.6931 - nse_metrics: 0.3069
# Epoch 16/200
# 15/15 [==============================] - 0s 474us/step - loss: 0.6779 - nse_metrics: 0.3221
# Epoch 17/200
# 15/15 [==============================] - 0s 477us/step - loss: 0.6659 - nse_metrics: 0.3341
# Epoch 18/200
# 15/15 [==============================] - 0s 412us/step - loss: 0.6555 - nse_metrics: 0.3445
# Epoch 19/200
# 15/15 [==============================] - 0s 534us/step - loss: 0.6450 - nse_metrics: 0.3550
# Epoch 20/200
# 15/15 [==============================] - 0s 454us/step - loss: 0.6337 - nse_metrics: 0.3663
# Epoch 21/200
# 15/15 [==============================] - 0s 594us/step - loss: 0.6220 - nse_metrics: 0.3780
# Epoch 22/200
# 15/15 [==============================] - 0s 444us/step - loss: 0.6107 - nse_metrics: 0.3893
# Epoch 23/200
# 15/15 [==============================] - 0s 535us/step - loss: 0.6007 - nse_metrics: 0.3993
# Epoch 24/200
# 15/15 [==============================] - 0s 423us/step - loss: 0.5924 - nse_metrics: 0.4076
# Epoch 25/200
# 15/15 [==============================] - 0s 530us/step - loss: 0.5849 - nse_metrics: 0.4151
# Epoch 26/200
# 15/15 [==============================] - 0s 442us/step - loss: 0.5769 - nse_metrics: 0.4231
# Epoch 27/200
# 15/15 [==============================] - 0s 495us/step - loss: 0.5680 - nse_metrics: 0.4320
# Epoch 28/200
# 15/15 [==============================] - 0s 489us/step - loss: 0.5587 - nse_metrics: 0.4413
# Epoch 29/200
# 15/15 [==============================] - 0s 490us/step - loss: 0.5502 - nse_metrics: 0.4498
# Epoch 30/200
# 15/15 [==============================] - 0s 472us/step - loss: 0.5428 - nse_metrics: 0.4572
# Epoch 31/200
# 15/15 [==============================] - 0s 480us/step - loss: 0.5358 - nse_metrics: 0.4642
# Epoch 32/200
# 15/15 [==============================] - 0s 478us/step - loss: 0.5285 - nse_metrics: 0.4715
# Epoch 33/200
# 15/15 [==============================] - 0s 389us/step - loss: 0.5207 - nse_metrics: 0.4793
# Epoch 34/200
# 15/15 [==============================] - 0s 446us/step - loss: 0.5131 - nse_metrics: 0.4869
# Epoch 35/200
# 15/15 [==============================] - 0s 512us/step - loss: 0.5065 - nse_metrics: 0.4935
# Epoch 36/200
# 15/15 [==============================] - 0s 569us/step - loss: 0.5008 - nse_metrics: 0.4992
# Epoch 37/200
# 15/15 [==============================] - 0s 365us/step - loss: 0.4953 - nse_metrics: 0.5047
# Epoch 38/200
# 15/15 [==============================] - 0s 546us/step - loss: 0.4897 - nse_metrics: 0.5103
# Epoch 39/200
# 15/15 [==============================] - 0s 443us/step - loss: 0.4846 - nse_metrics: 0.5154
# Epoch 40/200
# 15/15 [==============================] - 0s 463us/step - loss: 0.4804 - nse_metrics: 0.5196
# Epoch 41/200
# 15/15 [==============================] - 0s 496us/step - loss: 0.4768 - nse_metrics: 0.5232
# Epoch 42/200
# 15/15 [==============================] - 0s 466us/step - loss: 0.4731 - nse_metrics: 0.5269
# Epoch 43/200
# 15/15 [==============================] - 0s 429us/step - loss: 0.4693 - nse_metrics: 0.5307
# Epoch 44/200
# 15/15 [==============================] - 0s 565us/step - loss: 0.4656 - nse_metrics: 0.5344
# Epoch 45/200
# 15/15 [==============================] - 0s 377us/step - loss: 0.4623 - nse_metrics: 0.5377
# Epoch 46/200
# 15/15 [==============================] - 0s 561us/step - loss: 0.4588 - nse_metrics: 0.5412
# Epoch 47/200
# 15/15 [==============================] - 0s 468us/step - loss: 0.4550 - nse_metrics: 0.5450
# Epoch 48/200
# 15/15 [==============================] - 0s 488us/step - loss: 0.4512 - nse_metrics: 0.5488
# Epoch 49/200
# 15/15 [==============================] - 0s 488us/step - loss: 0.4477 - nse_metrics: 0.5523
# Epoch 50/200
# 15/15 [==============================] - 0s 506us/step - loss: 0.4445 - nse_metrics: 0.5555
# Epoch 51/200
# 15/15 [==============================] - 0s 569us/step - loss: 0.4412 - nse_metrics: 0.5588
# Epoch 52/200
# 15/15 [==============================] - 0s 429us/step - loss: 0.4380 - nse_metrics: 0.5620
# Epoch 53/200
# 15/15 [==============================] - 0s 494us/step - loss: 0.4352 - nse_metrics: 0.5648
# Epoch 54/200
# 15/15 [==============================] - 0s 534us/step - loss: 0.4326 - nse_metrics: 0.5674
# Epoch 55/200
# 15/15 [==============================] - 0s 518us/step - loss: 0.4302 - nse_metrics: 0.5698
# Epoch 56/200
# 15/15 [==============================] - 0s 514us/step - loss: 0.4278 - nse_metrics: 0.5722
# Epoch 57/200
# 15/15 [==============================] - 0s 463us/step - loss: 0.4256 - nse_metrics: 0.5744
# Epoch 58/200
# 15/15 [==============================] - 0s 484us/step - loss: 0.4236 - nse_metrics: 0.5764
# Epoch 59/200
# 15/15 [==============================] - 0s 482us/step - loss: 0.4216 - nse_metrics: 0.5784
# Epoch 60/200
# 15/15 [==============================] - 0s 477us/step - loss: 0.4196 - nse_metrics: 0.5804
# Epoch 61/200
# 15/15 [==============================] - 0s 478us/step - loss: 0.4177 - nse_metrics: 0.5823
# Epoch 62/200
# 15/15 [==============================] - 0s 489us/step - loss: 0.4158 - nse_metrics: 0.5842
# Epoch 63/200
# 15/15 [==============================] - 0s 441us/step - loss: 0.4137 - nse_metrics: 0.5863
# Epoch 64/200
# 15/15 [==============================] - 0s 560us/step - loss: 0.4116 - nse_metrics: 0.5884
# Epoch 65/200
# 15/15 [==============================] - 0s 529us/step - loss: 0.4096 - nse_metrics: 0.5904
# Epoch 66/200
# 15/15 [==============================] - 0s 436us/step - loss: 0.4075 - nse_metrics: 0.5925
# Epoch 67/200
# 15/15 [==============================] - 0s 495us/step - loss: 0.4054 - nse_metrics: 0.5946
# Epoch 68/200
# 15/15 [==============================] - 0s 509us/step - loss: 0.4034 - nse_metrics: 0.5966
# Epoch 69/200
# 15/15 [==============================] - 0s 520us/step - loss: 0.4014 - nse_metrics: 0.5986
# Epoch 70/200
# 15/15 [==============================] - 0s 528us/step - loss: 0.3994 - nse_metrics: 0.6006
# Epoch 71/200
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3975 - nse_metrics: 0.6025
# Epoch 72/200
# 15/15 [==============================] - 0s 453us/step - loss: 0.3956 - nse_metrics: 0.6044
# Epoch 73/200
# 15/15 [==============================] - 0s 463us/step - loss: 0.3938 - nse_metrics: 0.6062
# Epoch 74/200
# 15/15 [==============================] - 0s 467us/step - loss: 0.3919 - nse_metrics: 0.6081
# Epoch 75/200
# 15/15 [==============================] - 0s 476us/step - loss: 0.3902 - nse_metrics: 0.6098
# Epoch 76/200
# 15/15 [==============================] - 0s 518us/step - loss: 0.3884 - nse_metrics: 0.6116
# Epoch 77/200
# 15/15 [==============================] - 0s 423us/step - loss: 0.3867 - nse_metrics: 0.6133
# Epoch 78/200
# 15/15 [==============================] - 0s 476us/step - loss: 0.3850 - nse_metrics: 0.6150
# Epoch 79/200
# 15/15 [==============================] - 0s 447us/step - loss: 0.3834 - nse_metrics: 0.6166
# Epoch 80/200
# 15/15 [==============================] - 0s 468us/step - loss: 0.3818 - nse_metrics: 0.6182
# Epoch 81/200
# 15/15 [==============================] - 0s 515us/step - loss: 0.3803 - nse_metrics: 0.6197
# Epoch 82/200
# 15/15 [==============================] - 0s 433us/step - loss: 0.3787 - nse_metrics: 0.6213
# Epoch 83/200
# 15/15 [==============================] - 0s 423us/step - loss: 0.3772 - nse_metrics: 0.6228
# Epoch 84/200
# 15/15 [==============================] - 0s 462us/step - loss: 0.3757 - nse_metrics: 0.6243
# Epoch 85/200
# 15/15 [==============================] - 0s 451us/step - loss: 0.3743 - nse_metrics: 0.6257
# Epoch 86/200
# 15/15 [==============================] - 0s 532us/step - loss: 0.3729 - nse_metrics: 0.6271
# Epoch 87/200
# 15/15 [==============================] - 0s 399us/step - loss: 0.3716 - nse_metrics: 0.6284
# Epoch 88/200
# 15/15 [==============================] - 0s 414us/step - loss: 0.3703 - nse_metrics: 0.6297
# Epoch 89/200
# 15/15 [==============================] - 0s 421us/step - loss: 0.3691 - nse_metrics: 0.6309
# Epoch 90/200
# 15/15 [==============================] - 0s 475us/step - loss: 0.3680 - nse_metrics: 0.6320
# Epoch 91/200
# 15/15 [==============================] - 0s 492us/step - loss: 0.3669 - nse_metrics: 0.6331
# Epoch 92/200
# 15/15 [==============================] - 0s 485us/step - loss: 0.3659 - nse_metrics: 0.6341
# Epoch 93/200
# 15/15 [==============================] - 0s 516us/step - loss: 0.3649 - nse_metrics: 0.6351
# Epoch 94/200
# 15/15 [==============================] - 0s 494us/step - loss: 0.3640 - nse_metrics: 0.6360
# Epoch 95/200
# 15/15 [==============================] - 0s 572us/step - loss: 0.3631 - nse_metrics: 0.6369
# Epoch 96/200
# 15/15 [==============================] - 0s 477us/step - loss: 0.3623 - nse_metrics: 0.6377
# Epoch 97/200
# 15/15 [==============================] - 0s 516us/step - loss: 0.3615 - nse_metrics: 0.6385
# Epoch 98/200
# 15/15 [==============================] - 0s 502us/step - loss: 0.3611 - nse_metrics: 0.6389
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# Epoch 99/200
# 15/15 [==============================] - 0s 433us/step - loss: 0.3616 - nse_metrics: 0.6384
# Epoch 100/200
# 15/15 [==============================] - 0s 505us/step - loss: 0.3609 - nse_metrics: 0.6391
# Epoch 101/200
# 15/15 [==============================] - 0s 478us/step - loss: 0.3587 - nse_metrics: 0.6413
# Epoch 102/200
# 15/15 [==============================] - 0s 441us/step - loss: 0.3600 - nse_metrics: 0.6400
# Epoch 103/200
# 15/15 [==============================] - 0s 555us/step - loss: 0.3586 - nse_metrics: 0.6414
# Epoch 104/200
# 15/15 [==============================] - 0s 467us/step - loss: 0.3576 - nse_metrics: 0.6424
# Epoch 105/200
# 15/15 [==============================] - 0s 551us/step - loss: 0.3582 - nse_metrics: 0.6418
# Epoch 106/200
# 15/15 [==============================] - 0s 441us/step - loss: 0.3563 - nse_metrics: 0.6437
#
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 0.006399999558925629.
# Epoch 107/200
# 15/15 [==============================] - 0s 440us/step - loss: 0.3567 - nse_metrics: 0.6433
# Epoch 108/200
# 15/15 [==============================] - 0s 534us/step - loss: 0.3556 - nse_metrics: 0.6444
# Epoch 109/200
# 15/15 [==============================] - 0s 480us/step - loss: 0.3559 - nse_metrics: 0.6441
# Epoch 110/200
# 15/15 [==============================] - 0s 431us/step - loss: 0.3549 - nse_metrics: 0.6451
# Epoch 111/200
# 15/15 [==============================] - 0s 576us/step - loss: 0.3550 - nse_metrics: 0.6450
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 0.0051199994981288915.
# Epoch 112/200
# 15/15 [==============================] - 0s 470us/step - loss: 0.3542 - nse_metrics: 0.6458
# Epoch 113/200
# 15/15 [==============================] - 0s 494us/step - loss: 0.3542 - nse_metrics: 0.6458
# Epoch 114/200
# 15/15 [==============================] - 0s 489us/step - loss: 0.3536 - nse_metrics: 0.6464
# Epoch 115/200
# 15/15 [==============================] - 0s 492us/step - loss: 0.3537 - nse_metrics: 0.6463
# Epoch 116/200
# 15/15 [==============================] - 0s 438us/step - loss: 0.3531 - nse_metrics: 0.6469
# Epoch 117/200
# 15/15 [==============================] - 0s 490us/step - loss: 0.3531 - nse_metrics: 0.6469
# Epoch 118/200
# 15/15 [==============================] - 0s 487us/step - loss: 0.3526 - nse_metrics: 0.6474
# Epoch 119/200
# 15/15 [==============================] - 0s 446us/step - loss: 0.3524 - nse_metrics: 0.6476
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 0.004095999523997307.
# Epoch 120/200
# 15/15 [==============================] - 0s 424us/step - loss: 0.3521 - nse_metrics: 0.6479
# Epoch 121/200
# 15/15 [==============================] - 0s 395us/step - loss: 0.3518 - nse_metrics: 0.6482
# Epoch 122/200
# 15/15 [==============================] - 0s 501us/step - loss: 0.3518 - nse_metrics: 0.6482
# Epoch 123/200
# 15/15 [==============================] - 0s 484us/step - loss: 0.3514 - nse_metrics: 0.6486
# Epoch 124/200
# 15/15 [==============================] - 0s 457us/step - loss: 0.3513 - nse_metrics: 0.6487
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 0.0032767996191978457.
# Epoch 125/200
# 15/15 [==============================] - 0s 416us/step - loss: 0.3511 - nse_metrics: 0.6489
# Epoch 126/200
# 15/15 [==============================] - 0s 492us/step - loss: 0.3508 - nse_metrics: 0.6492
# Epoch 127/200
# 15/15 [==============================] - 0s 531us/step - loss: 0.3507 - nse_metrics: 0.6493
# Epoch 128/200
# 15/15 [==============================] - 0s 450us/step - loss: 0.3505 - nse_metrics: 0.6495
# Epoch 129/200
# 15/15 [==============================] - 0s 486us/step - loss: 0.3504 - nse_metrics: 0.6496
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 0.0026214396581053737.
# Epoch 130/200
# 15/15 [==============================] - 0s 452us/step - loss: 0.3502 - nse_metrics: 0.6498
# Epoch 131/200
# 15/15 [==============================] - 0s 450us/step - loss: 0.3501 - nse_metrics: 0.6499
# Epoch 132/200
# 15/15 [==============================] - 0s 450us/step - loss: 0.3499 - nse_metrics: 0.6501
# Epoch 133/200
# 15/15 [==============================] - 0s 472us/step - loss: 0.3498 - nse_metrics: 0.6502
# Epoch 134/200
# 15/15 [==============================] - 0s 453us/step - loss: 0.3497 - nse_metrics: 0.6503
# Restoring model weights from the end of the best epoch
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 0.0020971518009901048.
# Epoch 00134: early stopping

# %% [markdown]
# ### 2.4. Evaluate all the three models
#
# Here we call the `create_model()` and `test_model()` functions to evaluating the hybrid DL model, physical NN model, and common NN model.

# %%
####################
#  Hybrid DL model #
####################
model = create_model((test_x.shape[1], test_x.shape[2]), seed = 200, num_filters = 8, model_type='hybrid')
flow_hybrid = test_model(model, test_x, save_path_hybrid)

####################
# Physical NN model#
####################
model = create_model((test_x.shape[1], test_x.shape[2]), seed = 200, num_filters = 8, model_type='physical')
flow_physical = test_model(model, test_x, save_path_physical)

####################
#  Common NN model #
####################
model = create_model((test_x.shape[1], test_x.shape[2]), seed = 200, num_filters = 8, model_type='common')
#We use the feature means/stds of the training period for normalization
test_x_nor = (test_x - train_x_mean) / train_x_std 

flow_common = test_model(model, test_x_nor, save_path_common)
#We use the feature means/stds of the training period for recovery
flow_common = flow_common * train_y_std + train_y_mean

# %% [markdown]
# ## 3. Visualize the results
#
# First, we store all the results into a `pandas` data frame.

# %%
evaluate_set = test_set.loc[:, ['prcp(mm/day)','flow(mm)']]
evaluate_set['flow_obs'] = evaluate_set['flow(mm)']
evaluate_set['flow_hybrid'] = np.clip(flow_hybrid[0, :, :], a_min = 0, a_max = None)
evaluate_set['flow_physical'] = np.clip(flow_physical[0, :, :], a_min = 0, a_max = None)
evaluate_set['flow_common'] = np.clip(flow_common[0, :, :], a_min = 0, a_max = None)

# %% [markdown]
# As previously noted, the REAL evaluation period is from '2000-10-01', since the model needs one-year of data for spinning up the model. We implement an function `addYears()` for add 1 year to the starting days for testing.

# %%
def addYears(date, years):
    result = date + timedelta(366 * years)
    if years > 0:
        while result.year - date.year > years or date.month < result.month or date.day < result.day:
            result += timedelta(-1)
    elif years < 0:
        while result.year - date.year < years or date.month > result.month or date.day > result.day:
            result += timedelta(1)
    return result

evaluation_start = datetime.strftime(addYears(datetime.strptime(testing_start, '%Y-%m-%d'), 1), '%Y-%m-%d')
evaluation_end = testing_end

# %% [markdown]
# ### 3.1. Calculate Nash Sutcliffe Efficiency of predicted values

# %%
def calc_nse(y_true, y_pred):
    numerator = np.sum((y_pred - y_true) ** 2)
    denominator = np.sum((y_true - np.mean(y_true)) ** 2)

    return 1 - numerator / denominator

# We only evaluate the data in the evaluation period
date_range = pd.date_range(evaluation_start, evaluation_end) 
evaluate_set = evaluate_set[evaluate_set.index.isin(date_range)]

# Calculate respective NSE values
nse_hybrid = calc_nse(evaluate_set['flow_obs'].values, evaluate_set['flow_hybrid'].values)
nse_physical = calc_nse(evaluate_set['flow_obs'].values, evaluate_set['flow_physical'].values)
nse_common = calc_nse(evaluate_set['flow_obs'].values, evaluate_set['flow_common'].values)

# %% [markdown]
# ### 3.2. Plot the results by using the `matplotlib` library.

# %%
def evaluation_plot(ax, plot_set, plot_name, line_color, nse_values, basin_id):
    ax.plot(plot_set['flow_obs'], label="observation", color='black', ls='--')
    ax.plot(plot_set[plot_name], label="simulation", color=line_color, lw=1.5)
    ax.set_ylim([0, 30])
    ax.set_title(f"Basin {basin_id} - Test set NSE: {nse_values:.3f}")
    ax.set_ylabel("Streamflow (mm/day)")
    ax.legend()

plot_set = evaluate_set[evaluate_set.index.isin(pd.date_range(testing_start, testing_end))]

fig, [ax1, ax2, ax3] = plt.subplots(nrows=3, ncols=1, sharex='row', figsize=(15, 12))

evaluation_plot(ax1, plot_set, 'flow_hybrid', '#e41a1c', nse_hybrid, basin_id)
evaluation_plot(ax2, plot_set, 'flow_physical', '#377eb8', nse_physical, basin_id)
evaluation_plot(ax3, plot_set, 'flow_common', '#4daf4a', nse_common, basin_id)

ax1.annotate('Hybrid DL model', xy=(0.05, 0.9), xycoords='axes fraction', size=12)
ax2.annotate('Physical NN model', xy=(0.05, 0.9), xycoords='axes fraction', size=12)
ax3.annotate('Common NN model', xy=(0.05, 0.9), xycoords='axes fraction', size=12)

plt.show()
